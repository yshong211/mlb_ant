# %%
# !pip install ipython-sql
# !pip install mysqlclient

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine("mysql://mlb:HongKim@localhost/mlb")

# %%
query = "SELECT * FROM Pitches"
table = pd.read_sql_query(query, con=engine)
table.head(50)
# Out:
#        px     pz       ab_id  pitch_num
# 0   0.416  2.963  2015000001          1
# 1  -0.191  2.347  2015000001          2
# 2  -0.518  3.284  2015000001          3
# 3  -0.641  1.221  2015000001          4
# 4  -1.821  2.083  2015000001          5
# 5   0.627  2.397  2015000001          6
# 6  -1.088  1.610  2015000002          1
# 7  -0.257  2.047  2015000002          2
# 8   1.470  2.350  2015000003          1
# 9  -1.337  1.898  2015000003          2
# 10 -0.286  1.830  2015000003          3
# 11  0.200  2.643  2015000004          1
# 12 -0.741  2.930  2015000004          2
# 13 -0.711  1.971  2015000004          3
# 14 -1.539  1.525  2015000005          1
# 15 -0.881  1.888  2015000005          2
# 16  0.096  2.794  2015000005          3
# 17 -0.365  1.518  2015000005          4
# 18 -1.681  0.875  2015000005          5
# 19 -1.585  1.720  2015000006          1
# 20  0.008  2.602  2015000006          2
# 21  0.015  2.287  2015000007          1
# ...

# %%
query = "SELECT * FROM Pitches WHERE ab_id = 2018040493"
table = pd.read_sql_query(query, con=engine)
table.head(50)
# Out:
#       px     pz       ab_id  pitch_num
# 0  1.176  2.502  2018040493          1
# 1 -0.347  3.082  2018040493          2
# 2  0.701  2.546  2018040493          3
